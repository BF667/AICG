# %% [markdown]
# <a href="https://colab.research.google.com/github/BF667/AICG/blob/main/colab_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title ## **Install**


import os
import codecs
from IPython.display import clear_output
print("Installing requirements")
repo = "https://huggingface.co/R-Kentaren/AIGCP"

# !git clone $repo main_program  &> /dev/null
# %cd main_program &> /dev/null
# !pip install uv pyngrok &> /dev/null
# !uv pip install -r requirements.txt &> /dev/null
# !apt install sox &> /dev/null
clear_output()
print("Requirements installed!")

# %%
#@title **Run webui**


runtime = "src/webui.py"
# !git pull -q
# !python $runtime --share

# %% [markdown]
# this notebook fix made by [BF667](https://github.com/BF667/AICG)
#
#
# pls star my fork and follow me
